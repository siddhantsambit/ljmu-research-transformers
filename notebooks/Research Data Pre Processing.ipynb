# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# absl-py                       0.12.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.1.0
# appdirs                       1.4.4
# argcomplete                   1.12.3
# argon2-cffi                   20.1.0
# arviz                         0.11.2
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# async-generator               1.10
# atari-py                      0.2.9
# atomicwrites                  1.4.0
# attrs                         21.2.0
# audioread                     2.1.9
# autograd                      1.3
# Babel                         2.9.1
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        4.0.0
# blis                          0.4.1
# bokeh                         2.3.3
# ...

# %%
import json
from pathlib import Path
import pandas as pd
import torch
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls ./drive/MyDrive/Research_Transformer
# Out:
# squad  test  train  val

# %%
# !mkdir ./drive/MyDrive/Research_Transformer/test
# Out:
# mkdir: cannot create directory ‘./drive/MyDrive/Research_Transformer/test’: File exists

# %%
def read_squad(path):
    path = Path(path)
    with open(path, 'rb') as f:
        squad_dict = json.load(f)

    contexts = []
    questions = []
    answers = []
    answer_starts = []
    for group in squad_dict['data']:
        for passage in group['paragraphs']:
            context = passage['context']
            for qa in passage['qas']:
                question = qa['question']
                for answer in qa['answers']:
                    contexts.append(context)
                    questions.append(question)
                    answers.append(answer['text'])
                    answer_starts.append(answer['answer_start'])

    return contexts, questions, answers, answer_starts

# %%
# !mkdir ./drive/MyDrive/Research_Transformer/squad
# Out:
# mkdir: cannot create directory ‘./drive/MyDrive/Research_Transformer/squad’: File exists

# %%
# !wget https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json -O ./drive/MyDrive/Research_Transformer/squad/train-v2.0.json
# !wget https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v2.0.json -O ./drive/MyDrive/Research_Transformer/squad/dev-v2.0.json
# Out:
# --2021-08-15 18:18:34--  https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json
# Resolving rajpurkar.github.io (rajpurkar.github.io)... 185.199.109.153, 185.199.108.153, 185.199.110.153, ...
# Connecting to rajpurkar.github.io (rajpurkar.github.io)|185.199.109.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42123633 (40M) [application/json]
# Saving to: ‘./drive/MyDrive/Research_Transformer/squad/train-v2.0.json’
#
# ./drive/MyDrive/Res 100%[===================>]  40.17M  38.2MB/s    in 1.1s
#
# 2021-08-15 18:18:35 (38.2 MB/s) - ‘./drive/MyDrive/Research_Transformer/squad/train-v2.0.json’ saved [42123633/42123633]
#
# --2021-08-15 18:18:35--  https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v2.0.json
# Resolving rajpurkar.github.io (rajpurkar.github.io)... 185.199.109.153, 185.199.108.153, 185.199.110.153, ...
# Connecting to rajpurkar.github.io (rajpurkar.github.io)|185.199.109.153|:443... connected.
# ...

# %%
# !ls ./drive/MyDrive/Research_Transformer/squad
# Out:
# dev-v2.0.json  train-v2.0.json

# %%
train_contexts, train_questions, train_answers, train_answer_start = read_squad('./drive/MyDrive/Research_Transformer/squad/train-v2.0.json')

# %%
train_dict = {'context': train_contexts, 'question': train_questions, 'answer_text': train_answers, 'answer_start': train_answer_start}

# %%
train_qa_df = pd.DataFrame(train_dict)

# %%
train_qa_df.shape
# Out:
# (86821, 4)

# %%
train_qa_df
# Out:
#                                                  context  ... answer_start
# 0      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                  ...  ...          ...
# 86816  Kathmandu Metropolitan City (KMC), in order to...  ...          229
# 86817  Kathmandu Metropolitan City (KMC), in order to...  ...          414
# 86818  Kathmandu Metropolitan City (KMC), in order to...  ...          476
# 86819  Kathmandu Metropolitan City (KMC), in order to...  ...          199
# 86820  Kathmandu Metropolitan City (KMC), in order to...  ...            0
#
# [86821 rows x 4 columns]

# %%
# !mkdir ./drive/MyDrive/Research_Transformer/train
# Out:
# mkdir: cannot create directory ‘./drive/MyDrive/Research_Transformer/train’: File exists

# %%
# !ls ./drive/MyDrive/Research_Transformer
# Out:
# squad  test  train  val

# %%
train_qa_df.to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa.csv')
# Out:
#                                                  context  ... answer_start
# 0      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                  ...  ...          ...
# 86816  Kathmandu Metropolitan City (KMC), in order to...  ...          229
# 86817  Kathmandu Metropolitan City (KMC), in order to...  ...          414
# 86818  Kathmandu Metropolitan City (KMC), in order to...  ...          476
# 86819  Kathmandu Metropolitan City (KMC), in order to...  ...          199
# 86820  Kathmandu Metropolitan City (KMC), in order to...  ...            0
#
# [86821 rows x 4 columns]

# %%
train_qa_df.head(500).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_500.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_500.csv')
# Out:
#                                                context  ... answer_start
# 0    Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1    Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2    Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3    Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4    Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ..                                                 ...  ...          ...
# 495  In 2006, Beyoncé introduced her all-female tou...  ...          216
# 496  In 2006, Beyoncé introduced her all-female tou...  ...          343
# 497  Beyoncé has received praise for her stage pres...  ...           36
# 498  Beyoncé has received praise for her stage pres...  ...          445
# 499  Beyoncé has received praise for her stage pres...  ...           36
#
# [500 rows x 4 columns]

# %%
train_qa_df.head(1000).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_1k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_1k.csv')
# Out:
#                                                context  ... answer_start
# 0    Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1    Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2    Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3    Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4    Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ..                                                 ...  ...          ...
# 995  In Paris, Chopin encountered artists and other...  ...          385
# 996  Two Polish friends in Paris were also to play ...  ...          133
# 997  Two Polish friends in Paris were also to play ...  ...          218
# 998  Two Polish friends in Paris were also to play ...  ...          368
# 999  Two Polish friends in Paris were also to play ...  ...          133
#
# [1000 rows x 4 columns]

# %%
train_qa_df.head(1500).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_1_5k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_1_5k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                 ...  ...          ...
# 1495  In 1368, a Han Chinese revolt known as the Red...  ...          188
# 1496  In 1368, a Han Chinese revolt known as the Red...  ...          617
# 1497  As evident in his imperial edicts, the Hongwu ...  ...          139
# 1498  As evident in his imperial edicts, the Hongwu ...  ...          139
# 1499  As evident in his imperial edicts, the Hongwu ...  ...           72
#
# [1500 rows x 4 columns]

# %%
train_qa_df.head(2000).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_2k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_2k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                 ...  ...          ...
# 1995  On October 22, 2007, Apple reported quarterly ...  ...          236
# 1996  On January 22, 2008, Apple reported the best q...  ...            3
# 1997  On January 22, 2008, Apple reported the best q...  ...          184
# 1998  On January 22, 2008, Apple reported the best q...  ...          293
# 1999  On January 22, 2008, Apple reported the best q...  ...          199
#
# [2000 rows x 4 columns]

# %%
train_qa_df.head(2500).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_2_5k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_2_5k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                 ...  ...          ...
# 2495  On 13 March 2015, several members of the cast ...  ...          262
# 2496  On 13 March 2015, several members of the cast ...  ...          469
# 2497  On 13 March 2015, several members of the cast ...  ...            6
# 2498  On 13 March 2015, several members of the cast ...  ...          231
# 2499  On 13 March 2015, several members of the cast ...  ...          188
#
# [2500 rows x 4 columns]

# %%
train_qa_df.head(3000).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_3k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_3k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                 ...  ...          ...
# 2995  The State Council declared a three-day period ...  ...          435
# 2996  The State Council declared a three-day period ...  ...          103
# 2997  The State Council declared a three-day period ...  ...          687
# 2998  The State Council declared a three-day period ...  ...           29
# 2999  The Ningbo Organizing Committee of the Beijing...  ...           47
#
# [3000 rows x 4 columns]

# %%
train_qa_df.head(3500).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_3_5k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_3_5k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                 ...  ...          ...
# 3495  Real estate is a major force in the city's eco...  ...          252
# 3496  Real estate is a major force in the city's eco...  ...          432
# 3497  Real estate is a major force in the city's eco...  ...          565
# 3498  Real estate is a major force in the city's eco...  ...          678
# 3499  Real estate is a major force in the city's eco...  ...          164
#
# [3500 rows x 4 columns]

# %%
train_qa_df.head(4000).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_4k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_4k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                 ...  ...          ...
# 3995  In a 1964 interview, Lee remarked that her asp...  ...          474
# 3996  In a 1964 interview, Lee remarked that her asp...  ...          252
# 3997  In a 1964 interview, Lee remarked that her asp...  ...           73
# 3998  In a 1964 interview, Lee remarked that her asp...  ...          168
# 3999  Scholars argue that Lee's approach to class an...  ...          117
#
# [4000 rows x 4 columns]

# %%
train_qa_df.head(4500).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_4_5k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_4_5k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                 ...  ...          ...
# 4495  808s & Heartbreak, which features extensive us...  ...          164
# 4496  808s & Heartbreak, which features extensive us...  ...            0
# 4497  808s & Heartbreak, which features extensive us...  ...          164
# 4498  808s & Heartbreak, which features extensive us...  ...          220
# 4499  808s & Heartbreak, which features extensive us...  ...          546
#
# [4500 rows x 4 columns]

# %%
train_qa_df.head(5000).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_5k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_5k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                 ...  ...          ...
# 4995  The second truth is that the origin of dukkha ...  ...          433
# 4996  The second truth is that the origin of dukkha ...  ...           39
# 4997  The second truth is that the origin of dukkha ...  ...          151
# 4998  The second truth is that the origin of dukkha ...  ...          188
# 4999  The second truth is that the origin of dukkha ...  ...           25
#
# [5000 rows x 4 columns]

# %%
train_qa_df.head(10000).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_10k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_10k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                 ...  ...          ...
# 9995  The Oklahoman is Oklahoma City's major daily n...  ...          103
# 9996  The Oklahoman is Oklahoma City's major daily n...  ...          150
# 9997  The Oklahoman is Oklahoma City's major daily n...  ...          338
# 9998  There are numerous community and international...  ...          156
# 9999  There are numerous community and international...  ...          170
#
# [10000 rows x 4 columns]

# %%
train_qa_df.head(15000).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_15k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_15k.csv')
# Out:
#                                                  context  ... answer_start
# 0      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                  ...  ...          ...
# 14995  On July 20, 2009, Sports Business Journal repo...  ...            3
# 14996  On July 20, 2009, Sports Business Journal repo...  ...           18
# 14997  On July 20, 2009, Sports Business Journal repo...  ...           83
# 14998  On July 20, 2009, Sports Business Journal repo...  ...          144
# 14999  On July 20, 2009, Sports Business Journal repo...  ...          352
#
# [15000 rows x 4 columns]

# %%
train_qa_df.head(20000).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_20k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_20k.csv')
# Out:
#                                                  context  ... answer_start
# 0      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                  ...  ...          ...
# 19995  For example, 1920×1080p25 identifies progressi...  ...          392
# 19996  For example, 1920×1080p25 identifies progressi...  ...          548
# 19997  50 Hz systems support three scanning rates: 50...  ...           44
# 19998  50 Hz systems support three scanning rates: 50...  ...           62
# 19999  50 Hz systems support three scanning rates: 50...  ...          266
#
# [20000 rows x 4 columns]

# %%
train_qa_df.head(25000).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_25k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_25k.csv')
# Out:
#                                                  context  ... answer_start
# 0      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                  ...  ...          ...
# 24995  Draught beer's environmental impact can be 68%...  ...          410
# 24996  Draught beer's environmental impact can be 68%...  ...          429
# 24997  Drinking chilled beer began with the developme...  ...           52
# 24998  Drinking chilled beer began with the developme...  ...          213
# 24999  Drinking chilled beer began with the developme...  ...          335
#
# [25000 rows x 4 columns]

# %%
train_qa_df.head(30000).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_30k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_30k.csv')
# Out:
#                                                  context  ... answer_start
# 0      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                  ...  ...          ...
# 29995  The effect of these differences was accentuate...  ...          126
# 29996  The effect of these differences was accentuate...  ...          329
# 29997  The effect of these differences was accentuate...  ...          489
# 29998  The effect of these differences was accentuate...  ...          736
# 29999  At the Battle of Mars-la-Tours, the Prussian 1...  ...           80
#
# [30000 rows x 4 columns]

# %%
train_qa_df.head(35000).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_35k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_35k.csv')
# Out:
#                                                  context  ... answer_start
# 0      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                  ...  ...          ...
# 34995  Eleven days after Orsini's assassination attem...  ...          215
# 34996  Eleven days after Orsini's assassination attem...  ...          305
# 34997  Eleven days after Orsini's assassination attem...  ...          506
# 34998  Eleven days after Orsini's assassination attem...  ...           95
# 34999  Eleven days after Orsini's assassination attem...  ...          215
#
# [35000 rows x 4 columns]

# %%
train_qa_df.head(40000).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_40k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_40k.csv')
# Out:
#                                                  context  ... answer_start
# 0      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                  ...  ...          ...
# 39995  Mexico City has three zoos. Chapultepec Zoo, t...  ...          729
# 39996  Mexico City has three zoos. Chapultepec Zoo, t...  ...          847
# 39997  During Andrés López Obrador's administration a...  ...            7
# 39998  During Andrés López Obrador's administration a...  ...          213
# 39999  During Andrés López Obrador's administration a...  ...          485
#
# [40000 rows x 4 columns]

# %%
train_qa_df.head(45000).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_45k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_45k.csv')
# Out:
#                                                  context  ... answer_start
# 0      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                  ...  ...          ...
# 44995  The Ann Arbor News, owned by the Michigan-base...  ...          199
# 44996  The Ann Arbor News, owned by the Michigan-base...  ...          447
# 44997  Current publications in the city include the A...  ...          284
# 44998  Current publications in the city include the A...  ...          345
# 44999  Current publications in the city include the A...  ...          515
#
# [45000 rows x 4 columns]

# %%
train_qa_df.head(50000).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_50k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_50k.csv')
# Out:
#                                                  context  ... answer_start
# 0      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                  ...  ...          ...
# 49995  Early Asian immigrants experienced prejudice a...  ...          177
# 49996  Early Asian immigrants experienced prejudice a...  ...          401
# 49997  Early Asian immigrants experienced prejudice a...  ...          571
# 49998  Early Asian immigrants experienced prejudice a...  ...         1032
# 49999  Proponents of affirmative action recognize tha...  ...           62
#
# [50000 rows x 4 columns]

# %%
train_qa_df.head(55000).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_55k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_55k.csv')
# Out:
#                                                  context  ... answer_start
# 0      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                  ...  ...          ...
# 54995  Precipitation is moderate and somewhat evenly ...  ...          733
# 54996  Precipitation is moderate and somewhat evenly ...  ...          606
# 54997  Seen in panorama, Detroit's waterfront shows a...  ...           84
# 54998  Seen in panorama, Detroit's waterfront shows a...  ...          312
# 54999  Seen in panorama, Detroit's waterfront shows a...  ...          557
#
# [55000 rows x 4 columns]

# %%
train_qa_df.head(60000).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_60k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_60k.csv')
# Out:
#                                                  context  ... answer_start
# 0      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                  ...  ...          ...
# 59995  "New Labour" was first termed as an alternativ...  ...          219
# 59996  "New Labour" was first termed as an alternativ...  ...          232
# 59997  A perceived turning point was when Blair contr...  ...           80
# 59998  A perceived turning point was when Blair contr...  ...          119
# 59999  A perceived turning point was when Blair contr...  ...          516
#
# [60000 rows x 4 columns]

# %%
train_qa_df.head(65000).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_65k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_65k.csv')
# Out:
#                                                  context  ... answer_start
# 0      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                  ...  ...          ...
# 64995  Inflammatory diarrhea occurs when there is dam...  ...          476
# 64996  Diarrheal disease may have a negative impact o...  ...           27
# 64997  Diarrheal disease may have a negative impact o...  ...          149
# 64998  Diarrheal disease may have a negative impact o...  ...          212
# 64999  Diarrheal disease may have a negative impact o...  ...          518
#
# [65000 rows x 4 columns]

# %%
val_qa_df = pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa.csv',skiprows=65000,nrows=13000)

# %%
# !mkdir ./drive/MyDrive/Research_Transformer/val
# Out:
# mkdir: cannot create directory ‘./drive/MyDrive/Research_Transformer/val’: File exists

# %%
# !ls ./drive/MyDrive/Research_Transformer
# Out:
# squad  test  train  val

# %%
val_qa_df
# Out:
#       Diarrheal disease may have a negative impact on both physical fitness and mental development. "Early childhood malnutrition resulting from any cause reduces physical fitness and work productivity in adults," and diarrhea is a primary cause of childhood malnutrition. Further, evidence suggests that diarrheal disease has significant impacts on mental development and health; it has been shown that, even when controlling for helminth infection and early breastfeeding, children who had experienced severe diarrhea had significantly lower scores on a series of tests of intelligence.  ...  518
# ...

# %%
val_qa_df.to_csv(r'./drive/MyDrive/Research_Transformer/val/val_qa.csv', index=False, header=['context', 'question', 'answer_text', 'answer_start'])

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/val/val_qa.csv')
# Out:
#                                                  context  ... answer_start
# 0      Another possible cause of diarrhea is irritabl...  ...           38
# 1      Another possible cause of diarrhea is irritabl...  ...           98
# 2      Another possible cause of diarrhea is irritabl...  ...          302
# 3      Poverty is a good indicator of the rate of inf...  ...            0
# 4      Poverty is a good indicator of the rate of inf...  ...          143
# ...                                                  ...  ...          ...
# 12995  Fetuvalu offers the Cambridge syllabus. Motufo...  ...          418
# 12996  Fetuvalu offers the Cambridge syllabus. Motufo...  ...          460
# 12997  Fetuvalu offers the Cambridge syllabus. Motufo...  ...          518
# 12998  Fetuvalu offers the Cambridge syllabus. Motufo...  ...          238
# 12999  Required attendance at school is 10 years for ...  ...           33
#
# [13000 rows x 4 columns]

# %%
test_qa_df = pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa.csv',skiprows=78000)

# %%
# !mkdir ./drive/MyDrive/Research_Transformertest

# %%
# !ls ./drive/MyDrive/Research_Transformer
# Out:
# squad  test  train  val

# %%
test_qa_df
# Out:
#      Required attendance at school is 10 years for males and 11 years for females (2001). The adult literacy rate is 99.0% (2002). In 2010, there were 1,918 students who were taught by 109 teachers (98 certified and 11 uncertified). The teacher-pupil ratio for primary schools in Tuvalu is around 1:18 for all schools with the exception of Nauti School, which has a teacher-student ratio of 1:27. Nauti School on Funafuti is the largest primary in Tuvalu with more than 900 students (45 percent of the total primary school enrolment). The pupil-teacher ratio for Tuvalu is low compared to the Pacific region (ratio of 1:29).  ...   33
# ...

# %%
test_qa_df.to_csv(r'./drive/MyDrive/Research_Transformer/test/test_qa.csv', index=False, header=['context', 'question', 'answer_text', 'answer_start'])

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/test/test_qa.csv')
# Out:
#                                                 context  ... answer_start
# 0     Required attendance at school is 10 years for ...  ...           56
# 1     Required attendance at school is 10 years for ...  ...          112
# 2     Required attendance at school is 10 years for ...  ...          146
# 3     Required attendance at school is 10 years for ...  ...          292
# 4     Community Training Centres (CTCs) have been es...  ...            0
# ...                                                 ...  ...          ...
# 8816  Kathmandu Metropolitan City (KMC), in order to...  ...          229
# 8817  Kathmandu Metropolitan City (KMC), in order to...  ...          414
# 8818  Kathmandu Metropolitan City (KMC), in order to...  ...          476
# 8819  Kathmandu Metropolitan City (KMC), in order to...  ...          199
# 8820  Kathmandu Metropolitan City (KMC), in order to...  ...            0
#
# [8821 rows x 4 columns]

# %%
test_qa_df_without_answer = pd.read_csv('./drive/MyDrive/Research_Transformer/test/test_qa.csv', usecols=['context', 'question'])

# %%
test_qa_df_without_answer
# Out:
#                                                 context                                           question
# 0     Required attendance at school is 10 years for ...     How long are females required to go to school?
# 1     Required attendance at school is 10 years for ...      What was the literacy rate on Tuvalu in 2002?
# 2     Required attendance at school is 10 years for ...  How many students were in Tuvalu schools in 2010?
# 3     Required attendance at school is 10 years for ...  What si the teacher-student ratio for Tuvalu s...
# 4     Community Training Centres (CTCs) have been es...  What type of school has Tuvalu set up on each ...
# ...                                                 ...                                                ...
# 8816  Kathmandu Metropolitan City (KMC), in order to...  In what US state did Kathmandu first establish...
# 8817  Kathmandu Metropolitan City (KMC), in order to...               What was Yangon previously known as?
# ...

# %%
test_qa_df_without_answer.to_csv(r'./drive/MyDrive/Research_Transformer/test/test_qa_without_answer.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/test/test_qa_without_answer.csv')
# Out:
#                                                 context                                           question
# 0     Required attendance at school is 10 years for ...     How long are females required to go to school?
# 1     Required attendance at school is 10 years for ...      What was the literacy rate on Tuvalu in 2002?
# 2     Required attendance at school is 10 years for ...  How many students were in Tuvalu schools in 2010?
# 3     Required attendance at school is 10 years for ...  What si the teacher-student ratio for Tuvalu s...
# 4     Community Training Centres (CTCs) have been es...  What type of school has Tuvalu set up on each ...
# ...                                                 ...                                                ...
# 8816  Kathmandu Metropolitan City (KMC), in order to...  In what US state did Kathmandu first establish...
# 8817  Kathmandu Metropolitan City (KMC), in order to...               What was Yangon previously known as?
# ...

# %%
train_qa_df.shape
# Out:
# (86821, 4)

# %%
train_qa_df.head(8000).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_8k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_8k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                 ...  ...          ...
# 7995  The Canadian Special Operations Forces Command...  ...          134
# 7996  The Canadian Special Operations Forces Command...  ...          197
# 7997  The Canadian Special Operations Forces Command...  ...          310
# 7998  The Canadian Special Operations Forces Command...  ...          386
# 7999  Among other things, the Information Management...  ...           87
#
# [8000 rows x 4 columns]

# %%
train_qa_df.head(7000).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_7k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_7k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                 ...  ...          ...
# 6995  The Color Orange democracy group, led by Danis...  ...          344
# 6996  The Color Orange democracy group, led by Danis...  ...          661
# 6997   Macao: The event was held in Macau on May 3. ...  ...           39
# 6998   Macao: The event was held in Macau on May 3. ...  ...          137
# 6999   Macao: The event was held in Macau on May 3. ...  ...          570
#
# [7000 rows x 4 columns]

# %%
train_qa_df.head(6000).to_csv(r'./drive/MyDrive/Research_Transformer/train/train_qa_6k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/train/train_qa_6k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          269
# 1     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          207
# 2     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          526
# 3     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          166
# 4     Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...  ...          276
# ...                                                 ...  ...          ...
# 5995  Theories given for the success of Southerners ...  ...          665
# 5996  For five consecutive seasons, starting in seas...  ...          151
# 5997  For five consecutive seasons, starting in seas...  ...          242
# 5998  For five consecutive seasons, starting in seas...  ...          319
# 5999  For five consecutive seasons, starting in seas...  ...            4
#
# [6000 rows x 4 columns]

# %%
val_qa_df
# Out:
#       Diarrheal disease may have a negative impact on both physical fitness and mental development. "Early childhood malnutrition resulting from any cause reduces physical fitness and work productivity in adults," and diarrhea is a primary cause of childhood malnutrition. Further, evidence suggests that diarrheal disease has significant impacts on mental development and health; it has been shown that, even when controlling for helminth infection and early breastfeeding, children who had experienced severe diarrhea had significantly lower scores on a series of tests of intelligence.  ...  518
# ...

# %%
val_qa_df.head(1000).to_csv(r'./drive/MyDrive/Research_Transformer/val/val_qa_1k.csv', index=False, header=['context', 'question', 'answer_text', 'answer_start'])

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/val/val_qa_1k.csv')
# Out:
#                                                context  ... answer_start
# 0    Another possible cause of diarrhea is irritabl...  ...           38
# 1    Another possible cause of diarrhea is irritabl...  ...           98
# 2    Another possible cause of diarrhea is irritabl...  ...          302
# 3    Poverty is a good indicator of the rate of inf...  ...            0
# 4    Poverty is a good indicator of the rate of inf...  ...          143
# ..                                                 ...  ...          ...
# 995  Spirit possession has been documented in moder...  ...            0
# 996  Spirit possession has been documented in moder...  ...          233
# 997  Spirit possession has been documented in moder...  ...          421
# 998  Spirit possession has been documented in moder...  ...          431
# 999  Spirit possession has been documented in moder...  ...          528
#
# [1000 rows x 4 columns]

# %%
val_qa_df.head(2000).to_csv(r'./drive/MyDrive/Research_Transformer/val/val_qa_2k.csv', index=False, header=['context', 'question', 'answer_text', 'answer_start'])

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/val/val_qa_2k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Another possible cause of diarrhea is irritabl...  ...           38
# 1     Another possible cause of diarrhea is irritabl...  ...           98
# 2     Another possible cause of diarrhea is irritabl...  ...          302
# 3     Poverty is a good indicator of the rate of inf...  ...            0
# 4     Poverty is a good indicator of the rate of inf...  ...          143
# ...                                                 ...  ...          ...
# 1995  Also emerging during this period was New York'...  ...          263
# 1996  Also emerging during this period was New York'...  ...          515
# 1997  Also emerging during this period was New York'...  ...          642
# 1998  Also emerging during this period was New York'...  ...          407
# 1999  Also emerging during this period was New York'...  ...           66
#
# [2000 rows x 4 columns]

# %%
val_qa_df.head(3000).to_csv(r'./drive/MyDrive/Research_Transformer/val/val_qa_3k.csv', index=False, header=['context', 'question', 'answer_text', 'answer_start'])

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/val/val_qa_3k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Another possible cause of diarrhea is irritabl...  ...           38
# 1     Another possible cause of diarrhea is irritabl...  ...           98
# 2     Another possible cause of diarrhea is irritabl...  ...          302
# 3     Poverty is a good indicator of the rate of inf...  ...            0
# 4     Poverty is a good indicator of the rate of inf...  ...          143
# ...                                                 ...  ...          ...
# 2995  In 1989, Gaddafi was overjoyed by the foundati...  ...          424
# 2996  In 1989, Gaddafi was overjoyed by the foundati...  ...          504
# 2997  In 1989, Gaddafi was overjoyed by the foundati...  ...          753
# 2998  In 1989, Gaddafi was overjoyed by the foundati...  ...          906
# 2999  As the 20th century came to a close, Gaddafi i...  ...          345
#
# [3000 rows x 4 columns]

# %%
val_qa_df.head(4000).to_csv(r'./drive/MyDrive/Research_Transformer/val/val_qa_4k.csv', index=False, header=['context', 'question', 'answer_text', 'answer_start'])

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/val/val_qa_4k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Another possible cause of diarrhea is irritabl...  ...           38
# 1     Another possible cause of diarrhea is irritabl...  ...           98
# 2     Another possible cause of diarrhea is irritabl...  ...          302
# 3     Poverty is a good indicator of the rate of inf...  ...            0
# 4     Poverty is a good indicator of the rate of inf...  ...          143
# ...                                                 ...  ...          ...
# 3995  In 2007, it was discovered that the upper trop...  ...          291
# 3996  In 2007, it was discovered that the upper trop...  ...          474
# 3997  In 2007, it was discovered that the upper trop...  ...          660
# 3998  The Scooter is another storm, a white cloud gr...  ...            0
# 3999  The Scooter is another storm, a white cloud gr...  ...          175
#
# [4000 rows x 4 columns]

# %%
test_qa_df
# Out:
#      Required attendance at school is 10 years for males and 11 years for females (2001). The adult literacy rate is 99.0% (2002). In 2010, there were 1,918 students who were taught by 109 teachers (98 certified and 11 uncertified). The teacher-pupil ratio for primary schools in Tuvalu is around 1:18 for all schools with the exception of Nauti School, which has a teacher-student ratio of 1:27. Nauti School on Funafuti is the largest primary in Tuvalu with more than 900 students (45 percent of the total primary school enrolment). The pupil-teacher ratio for Tuvalu is low compared to the Pacific region (ratio of 1:29).  ...   33
# ...

# %%
test_qa_df_without_answer
# Out:
#                                                 context                                           question
# 0     Required attendance at school is 10 years for ...     How long are females required to go to school?
# 1     Required attendance at school is 10 years for ...      What was the literacy rate on Tuvalu in 2002?
# 2     Required attendance at school is 10 years for ...  How many students were in Tuvalu schools in 2010?
# 3     Required attendance at school is 10 years for ...  What si the teacher-student ratio for Tuvalu s...
# 4     Community Training Centres (CTCs) have been es...  What type of school has Tuvalu set up on each ...
# ...                                                 ...                                                ...
# 8816  Kathmandu Metropolitan City (KMC), in order to...  In what US state did Kathmandu first establish...
# 8817  Kathmandu Metropolitan City (KMC), in order to...               What was Yangon previously known as?
# ...

# %%
test_qa_df.head(1000).to_csv(r'./drive/MyDrive/Research_Transformer/test/test_qa_1k.csv', index=False, header=['context', 'question', 'answer_text', 'answer_start'])

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/test/test_qa_1k.csv')
# Out:
#                                                context  ... answer_start
# 0    Required attendance at school is 10 years for ...  ...           56
# 1    Required attendance at school is 10 years for ...  ...          112
# 2    Required attendance at school is 10 years for ...  ...          146
# 3    Required attendance at school is 10 years for ...  ...          292
# 4    Community Training Centres (CTCs) have been es...  ...            0
# ..                                                 ...  ...          ...
# 995  In the US, one kilowatt-hour (3.6 MJ) of elect...  ...          291
# 996  In the US, one kilowatt-hour (3.6 MJ) of elect...  ...          414
# 997  Machine vision systems often require bright an...  ...            0
# 998  Machine vision systems often require bright an...  ...           74
# 999  Machine vision systems often require bright an...  ...          222
#
# [1000 rows x 4 columns]

# %%
test_qa_df_without_answer.head(1000).to_csv(r'./drive/MyDrive/Research_Transformer/test/test_qa_without_answer_1k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/test/test_qa_without_answer_1k.csv')
# Out:
#                                                context                                           question
# 0    Required attendance at school is 10 years for ...     How long are females required to go to school?
# 1    Required attendance at school is 10 years for ...      What was the literacy rate on Tuvalu in 2002?
# 2    Required attendance at school is 10 years for ...  How many students were in Tuvalu schools in 2010?
# 3    Required attendance at school is 10 years for ...  What si the teacher-student ratio for Tuvalu s...
# 4    Community Training Centres (CTCs) have been es...  What type of school has Tuvalu set up on each ...
# ..                                                 ...                                                ...
# 995  In the US, one kilowatt-hour (3.6 MJ) of elect...  A 6-watt LED left on for 10 hours a day will e...
# 996  In the US, one kilowatt-hour (3.6 MJ) of elect...  How much can a building's carbon footprint be ...
# ...

# %%
test_qa_df.head(2000).to_csv(r'./drive/MyDrive/Research_Transformer/test/test_qa_2k.csv', index=False, header=['context', 'question', 'answer_text', 'answer_start'])

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/test/test_qa_2k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Required attendance at school is 10 years for ...  ...           56
# 1     Required attendance at school is 10 years for ...  ...          112
# 2     Required attendance at school is 10 years for ...  ...          146
# 3     Required attendance at school is 10 years for ...  ...          292
# 4     Community Training Centres (CTCs) have been es...  ...            0
# ...                                                 ...  ...          ...
# 1995  But early in the 16th century, a brilliant new...  ...          162
# 1996  But early in the 16th century, a brilliant new...  ...          525
# 1997  But early in the 16th century, a brilliant new...  ...          677
# 1998  The painters of the early Renaissance used two...  ...          145
# 1999  The painters of the early Renaissance used two...  ...          192
#
# [2000 rows x 4 columns]

# %%
test_qa_df_without_answer.head(2000).to_csv(r'./drive/MyDrive/Research_Transformer/test/test_qa_without_answer_2k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/test/test_qa_without_answer_2k.csv')
# Out:
#                                                 context                                           question
# 0     Required attendance at school is 10 years for ...     How long are females required to go to school?
# 1     Required attendance at school is 10 years for ...      What was the literacy rate on Tuvalu in 2002?
# 2     Required attendance at school is 10 years for ...  How many students were in Tuvalu schools in 2010?
# 3     Required attendance at school is 10 years for ...  What si the teacher-student ratio for Tuvalu s...
# 4     Community Training Centres (CTCs) have been es...  What type of school has Tuvalu set up on each ...
# ...                                                 ...                                                ...
# 1995  But early in the 16th century, a brilliant new...  During what years was the Aztec Empire conquered?
# 1996  But early in the 16th century, a brilliant new...  How often could the Mexican cochineal be harve...
# ...

# %%
test_qa_df.head(3000).to_csv(r'./drive/MyDrive/Research_Transformer/test/test_qa_3k.csv', index=False, header=['context', 'question', 'answer_text', 'answer_start'])

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/test/test_qa_3k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Required attendance at school is 10 years for ...  ...           56
# 1     Required attendance at school is 10 years for ...  ...          112
# 2     Required attendance at school is 10 years for ...  ...          146
# 3     Required attendance at school is 10 years for ...  ...          292
# 4     Community Training Centres (CTCs) have been es...  ...            0
# ...                                                 ...  ...          ...
# 2995  Rome had no separate priestly caste or class. ...  ...           12
# 2996  Rome had no separate priestly caste or class. ...  ...           50
# 2997  Rome had no separate priestly caste or class. ...  ...          198
# 2998  Rome had no separate priestly caste or class. ...  ...          343
# 2999  Rome had no separate priestly caste or class. ...  ...          539
#
# [3000 rows x 4 columns]

# %%
test_qa_df_without_answer.head(3000).to_csv(r'./drive/MyDrive/Research_Transformer/test/test_qa_without_answer_3k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/test/test_qa_without_answer_3k.csv')
# Out:
#                                                 context                                           question
# 0     Required attendance at school is 10 years for ...     How long are females required to go to school?
# 1     Required attendance at school is 10 years for ...      What was the literacy rate on Tuvalu in 2002?
# 2     Required attendance at school is 10 years for ...  How many students were in Tuvalu schools in 2010?
# 3     Required attendance at school is 10 years for ...  What si the teacher-student ratio for Tuvalu s...
# 4     Community Training Centres (CTCs) have been es...  What type of school has Tuvalu set up on each ...
# ...                                                 ...                                                ...
# 2995  Rome had no separate priestly caste or class. ...  What was lacking as to the profession of a pri...
# 2996  Rome had no separate priestly caste or class. ...  What authority in a community sponsored religi...
# ...

# %%
test_qa_df.head(4000).to_csv(r'./drive/MyDrive/Research_Transformer/test/test_qa_4k.csv', index=False, header=['context', 'question', 'answer_text', 'answer_start'])

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/test/test_qa_4k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Required attendance at school is 10 years for ...  ...           56
# 1     Required attendance at school is 10 years for ...  ...          112
# 2     Required attendance at school is 10 years for ...  ...          146
# 3     Required attendance at school is 10 years for ...  ...          292
# 4     Community Training Centres (CTCs) have been es...  ...            0
# ...                                                 ...  ...          ...
# 3995  Juscelino Kubitschek, President of Brazil from...  ...            0
# 3996  Juscelino Kubitschek, President of Brazil from...  ...          337
# 3997  Juscelino Kubitschek, President of Brazil from...  ...          538
# 3998  Until the 1980s, the governor of the Federal D...  ...          190
# 3999  Until the 1980s, the governor of the Federal D...  ...          221
#
# [4000 rows x 4 columns]

# %%
test_qa_df_without_answer.head(4000).to_csv(r'./drive/MyDrive/Research_Transformer/test/test_qa_without_answer_4k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/test/test_qa_without_answer_4k.csv')
# Out:
#                                                 context                                           question
# 0     Required attendance at school is 10 years for ...     How long are females required to go to school?
# 1     Required attendance at school is 10 years for ...      What was the literacy rate on Tuvalu in 2002?
# 2     Required attendance at school is 10 years for ...  How many students were in Tuvalu schools in 2010?
# 3     Required attendance at school is 10 years for ...  What si the teacher-student ratio for Tuvalu s...
# 4     Community Training Centres (CTCs) have been es...  What type of school has Tuvalu set up on each ...
# ...                                                 ...                                                ...
# 3995  Juscelino Kubitschek, President of Brazil from...                     Who ordered Brasilia be built?
# 3996  Juscelino Kubitschek, President of Brazil from...  How many people competed to be Brasilia's urba...
# ...

# %%
val_qa_df
# Out:
#       Diarrheal disease may have a negative impact on both physical fitness and mental development. "Early childhood malnutrition resulting from any cause reduces physical fitness and work productivity in adults," and diarrhea is a primary cause of childhood malnutrition. Further, evidence suggests that diarrheal disease has significant impacts on mental development and health; it has been shown that, even when controlling for helminth infection and early breastfeeding, children who had experienced severe diarrhea had significantly lower scores on a series of tests of intelligence.  ...  518
# ...

# %%
val_qa_df.head(10000).to_csv(r'./drive/MyDrive/Research_Transformer/val/val_qa_10k.csv', index=False, header=['context', 'question', 'answer_text', 'answer_start'])

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/val/val_qa_10k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Another possible cause of diarrhea is irritabl...  ...           38
# 1     Another possible cause of diarrhea is irritabl...  ...           98
# 2     Another possible cause of diarrhea is irritabl...  ...          302
# 3     Poverty is a good indicator of the rate of inf...  ...            0
# 4     Poverty is a good indicator of the rate of inf...  ...          143
# ...                                                 ...  ...          ...
# 9995  The Japanese leadership was aware that a total...  ...          510
# 9996  In the early hours of 7 December (Hawaiian tim...  ...          196
# 9997  In the early hours of 7 December (Hawaiian tim...  ...          275
# 9998  In the early hours of 7 December (Hawaiian tim...  ...          345
# 9999  In the early hours of 7 December (Hawaiian tim...  ...          661
#
# [10000 rows x 4 columns]

# %%
val_qa_df.head(9000).to_csv(r'./drive/MyDrive/Research_Transformer/val/val_qa_9k.csv', index=False, header=['context', 'question', 'answer_text', 'answer_start'])

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/val/val_qa_9k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Another possible cause of diarrhea is irritabl...  ...           38
# 1     Another possible cause of diarrhea is irritabl...  ...           98
# 2     Another possible cause of diarrhea is irritabl...  ...          302
# 3     Poverty is a good indicator of the rate of inf...  ...            0
# 4     Poverty is a good indicator of the rate of inf...  ...          143
# ...                                                 ...  ...          ...
# 8995  For those that remained under the Ottoman Empi...  ...          308
# 8996  For those that remained under the Ottoman Empi...  ...          445
# 8997  For those that remained under the Ottoman Empi...  ...          561
# 8998  The roots of Greek success in the Ottoman Empi...  ...           66
# 8999  The roots of Greek success in the Ottoman Empi...  ...          120
#
# [9000 rows x 4 columns]

# %%
val_qa_df.head(8000).to_csv(r'./drive/MyDrive/Research_Transformer/val/val_qa_8k.csv', index=False, header=['context', 'question', 'answer_text', 'answer_start'])

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/val/val_qa_8k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Another possible cause of diarrhea is irritabl...  ...           38
# 1     Another possible cause of diarrhea is irritabl...  ...           98
# 2     Another possible cause of diarrhea is irritabl...  ...          302
# 3     Poverty is a good indicator of the rate of inf...  ...            0
# 4     Poverty is a good indicator of the rate of inf...  ...          143
# ...                                                 ...  ...          ...
# 7995  The city's elevation is 2,643 ft (806 m) above...  ...           24
# 7996  The city's elevation is 2,643 ft (806 m) above...  ...          155
# 7997  The city's elevation is 2,643 ft (806 m) above...  ...          331
# 7998  The city's elevation is 2,643 ft (806 m) above...  ...          254
# 7999  The city's elevation is 2,643 ft (806 m) above...  ...          369
#
# [8000 rows x 4 columns]

# %%
val_qa_df.head(7000).to_csv(r'./drive/MyDrive/Research_Transformer/val/val_qa_7k.csv', index=False, header=['context', 'question', 'answer_text', 'answer_start'])

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/val/val_qa_7k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Another possible cause of diarrhea is irritabl...  ...           38
# 1     Another possible cause of diarrhea is irritabl...  ...           98
# 2     Another possible cause of diarrhea is irritabl...  ...          302
# 3     Poverty is a good indicator of the rate of inf...  ...            0
# 4     Poverty is a good indicator of the rate of inf...  ...          143
# ...                                                 ...  ...          ...
# 6995  The internal classification of this group has ...  ...          401
# 6996  Recent studies, as by the APG, show that the m...  ...           61
# 6997  Recent studies, as by the APG, show that the m...  ...          170
# 6998  Recent studies, as by the APG, show that the m...  ...          330
# 6999  Recent studies, as by the APG, show that the m...  ...          353
#
# [7000 rows x 4 columns]

# %%
val_qa_df.head(6000).to_csv(r'./drive/MyDrive/Research_Transformer/val/val_qa_6k.csv', index=False, header=['context', 'question', 'answer_text', 'answer_start'])

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/val/val_qa_6k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Another possible cause of diarrhea is irritabl...  ...           38
# 1     Another possible cause of diarrhea is irritabl...  ...           98
# 2     Another possible cause of diarrhea is irritabl...  ...          302
# 3     Poverty is a good indicator of the rate of inf...  ...            0
# 4     Poverty is a good indicator of the rate of inf...  ...          143
# ...                                                 ...  ...          ...
# 5995  BJTs have three terminals, corresponding to th...  ...          945
# 5996  BJTs have three terminals, corresponding to th...  ...         1017
# 5997  In a FET, the drain-to-source current flows vi...  ...          156
# 5998  In a FET, the drain-to-source current flows vi...  ...          325
# 5999  In a FET, the drain-to-source current flows vi...  ...          513
#
# [6000 rows x 4 columns]

# %%
test_qa_df
# Out:
#      Required attendance at school is 10 years for males and 11 years for females (2001). The adult literacy rate is 99.0% (2002). In 2010, there were 1,918 students who were taught by 109 teachers (98 certified and 11 uncertified). The teacher-pupil ratio for primary schools in Tuvalu is around 1:18 for all schools with the exception of Nauti School, which has a teacher-student ratio of 1:27. Nauti School on Funafuti is the largest primary in Tuvalu with more than 900 students (45 percent of the total primary school enrolment). The pupil-teacher ratio for Tuvalu is low compared to the Pacific region (ratio of 1:29).  ...   33
# ...

# %%
test_qa_df_without_answer
# Out:
#                                                 context                                           question
# 0     Required attendance at school is 10 years for ...     How long are females required to go to school?
# 1     Required attendance at school is 10 years for ...      What was the literacy rate on Tuvalu in 2002?
# 2     Required attendance at school is 10 years for ...  How many students were in Tuvalu schools in 2010?
# 3     Required attendance at school is 10 years for ...  What si the teacher-student ratio for Tuvalu s...
# 4     Community Training Centres (CTCs) have been es...  What type of school has Tuvalu set up on each ...
# ...                                                 ...                                                ...
# 8816  Kathmandu Metropolitan City (KMC), in order to...  In what US state did Kathmandu first establish...
# 8817  Kathmandu Metropolitan City (KMC), in order to...               What was Yangon previously known as?
# ...

# %%
test_qa_df.head(5000).to_csv(r'./drive/MyDrive/Research_Transformer/test/test_qa_5k.csv', index=False, header=['context', 'question', 'answer_text', 'answer_start'])

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/test/test_qa_5k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Required attendance at school is 10 years for ...  ...           56
# 1     Required attendance at school is 10 years for ...  ...          112
# 2     Required attendance at school is 10 years for ...  ...          146
# 3     Required attendance at school is 10 years for ...  ...          292
# 4     Community Training Centres (CTCs) have been es...  ...            0
# ...                                                 ...  ...          ...
# 4995  In the years that followed, Eisenhower increas...  ...          106
# 4996  In the years that followed, Eisenhower increas...  ...          313
# 4997  In the years that followed, Eisenhower increas...  ...          416
# 4998  In the years that followed, Eisenhower increas...  ...          497
# 4999  In the years that followed, Eisenhower increas...  ...          561
#
# [5000 rows x 4 columns]

# %%
test_qa_df_without_answer.head(5000).to_csv(r'./drive/MyDrive/Research_Transformer/test/test_qa_without_answer_5k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/test/test_qa_without_answer_5k.csv')
# Out:
#                                                 context                                           question
# 0     Required attendance at school is 10 years for ...     How long are females required to go to school?
# 1     Required attendance at school is 10 years for ...      What was the literacy rate on Tuvalu in 2002?
# 2     Required attendance at school is 10 years for ...  How many students were in Tuvalu schools in 2010?
# 3     Required attendance at school is 10 years for ...  What si the teacher-student ratio for Tuvalu s...
# 4     Community Training Centres (CTCs) have been es...  What type of school has Tuvalu set up on each ...
# ...                                                 ...                                                ...
# 4995  In the years that followed, Eisenhower increas...  How many soldiers did Eisenhower ultimately se...
# 4996  In the years that followed, Eisenhower increas...  How many days did the President of South Vietn...
# ...

# %%
test_qa_df.head(6000).to_csv(r'./drive/MyDrive/Research_Transformer/test/test_qa_6k.csv', index=False, header=['context', 'question', 'answer_text', 'answer_start'])

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/test/test_qa_6k.csv')
# Out:
#                                                 context  ... answer_start
# 0     Required attendance at school is 10 years for ...  ...           56
# 1     Required attendance at school is 10 years for ...  ...          112
# 2     Required attendance at school is 10 years for ...  ...          146
# 3     Required attendance at school is 10 years for ...  ...          292
# 4     Community Training Centres (CTCs) have been es...  ...            0
# ...                                                 ...  ...          ...
# 5995  In the second decade of the 21st century the P...  ...          273
# 5996  In the second decade of the 21st century the P...  ...          376
# 5997  In the second decade of the 21st century the P...  ...          392
# 5998  In the second decade of the 21st century the P...  ...          654
# 5999  Agriculture in Portugal is based on small to m...  ...           36
#
# [6000 rows x 4 columns]

# %%
test_qa_df_without_answer.head(6000).to_csv(r'./drive/MyDrive/Research_Transformer/test/test_qa_without_answer_6k.csv', index=False)

# %%
pd.read_csv('./drive/MyDrive/Research_Transformer/test/test_qa_without_answer_6k.csv')
# Out:
#                                                 context                                           question
# 0     Required attendance at school is 10 years for ...     How long are females required to go to school?
# 1     Required attendance at school is 10 years for ...      What was the literacy rate on Tuvalu in 2002?
# 2     Required attendance at school is 10 years for ...  How many students were in Tuvalu schools in 2010?
# 3     Required attendance at school is 10 years for ...  What si the teacher-student ratio for Tuvalu s...
# 4     Community Training Centres (CTCs) have been es...  What type of school has Tuvalu set up on each ...
# ...                                                 ...                                                ...
# 5995  In the second decade of the 21st century the P...   In what year was the economic bailout agreed to?
# 5996  In the second decade of the 21st century the P...  How much money was agreed to in the financial ...
# ...
